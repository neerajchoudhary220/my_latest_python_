# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/choose_lang.csv')
df.head()
# Out:
#                                            quesetion  lang label
# 0  find the all list of input in html? intput lis...     1  Html
# 1                                 input list in html     1  Html
# 2                                               html     1  Html
# 3                       write file input tag in html     1  Html
# 4                                 <form> tag in hitm     1  Html

# %%
sort_df = df.sort_values(by=['lang'])

# %%
sort_df
# Out:
#                                             quesetion  lang      label
# 0   find the all list of input in html? intput lis...     1       Html
# 35                                       tags of html     1       Html
# 36                                          html tags     1       Html
# 38                              write comment in html     1       Html
# 7                                          li in html     1       Html
# 6                          image tag. img tag in html     1       Html
# 8                                 image src tag html      1       Html
# 4                                  <form> tag in hitm     1       Html
# 3                        write file input tag in html     1       Html
# 2                                                html     1       Html
# 1                                  input list in html     1       Html
# 5                                form example in html     1       Html
# ...

# %%
sort_df.to_excel('choose_lang.xlsx', sheet_name='web_lang', index=False)

# %%
sort_df.head()
# Out:
#                                             quesetion  lang label
# 0   find the all list of input in html? intput lis...     1  Html
# 35                                       tags of html     1  Html
# 36                                          html tags     1  Html
# 38                              write comment in html     1  Html
# 7                                          li in html     1  Html

# %%
html_df = sort_df[sort_df.lang==1]

# %%
html_df
# Out:
#                                             quesetion  lang label
# 0   find the all list of input in html? intput lis...     1  Html
# 35                                       tags of html     1  Html
# 36                                          html tags     1  Html
# 38                              write comment in html     1  Html
# 7                                          li in html     1  Html
# 6                          image tag. img tag in html     1  Html
# 8                                 image src tag html      1  Html
# 4                                  <form> tag in hitm     1  Html
# 3                        write file input tag in html     1  Html
# 2                                                html     1  Html
# 1                                  input list in html     1  Html
# 5                                form example in html     1  Html
# 43                                       comment html     1  Html

# %%
#convert html_df to excel
html_df.to_excel('html.xlsx', sheet_name ='html', index=False)

# %%
bootstrap_df = sort_df[sort_df.lang==2]
bootstrap_df
# Out:
#                                   quesetion  lang      label
# 23                create card in bootstrap4     2  Bootstrap
# 34                     buttons in bootstrap     2  Bootstrap
# 33               form example in bootstrap4     2  Bootstrap
# 30  write submit button tag with bootstrap4     2  Bootstrap
# 24                         bootstrap4 color     2  Bootstrap
# 44                     bootstrap color code     2  Bootstrap
# 9                                 bootstrap     2  Bootstrap
# 10                 model popup in bootstrap     2  Bootstrap
# 11                       badge in bootstrap     2  Bootstrap

# %%
#convert bootstrap_df to excel
bootstrap_df.to_excel('bootstrap.xlsx', sheet_name="bootstrap", index=False)

# %%
#js excel
js = sort_df[sort_df.lang==3].head()
js.to_excel('js.xlsx',sheet_name="js", index=False)
