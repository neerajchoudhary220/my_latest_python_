# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.6.0

# %%
import matplotlib.pyplot as plt,numpy as np
# x =np.array([20,30])
# y=np.array([40,50])
x = [20,12]
y=[20,10]
plt.plot(x,y,'o')
plt.show()
